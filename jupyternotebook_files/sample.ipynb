# %% [markdown]
# # Зертханалық жұмыс №1
# ### Тақырыбы: 'Ықтималдықтың статистикалық және геометриялық анықтамалары'
#
# ---
#
# **Топ:** ______________
#
# **Аты-жөні:** _________________________

# %% [markdown]
# ## Жұмыстың мақсаты
#
# *Осы жерге әдістемелік нұсқаулықта көрсетілген жұмыстың мақсатын көшіріп жазыңыз...*
#
# Толтыру міндетті емес

# %% [markdown]
# ## Теориялық кіріспе
#
# *Осы жерге зертханалық жұмысты орындау үшін қажетті негізгі формулалар мен анықтамаларды қысқаша жазыңыз (мысалы, салыстырмалы жиілік, геометриялық ықтималдық формулалары).*
#
# Толтыру міндетті емес

# %% [markdown]
# ---
# # Жұмыстың орындалу барысы

# %% [markdown]
# ### 1-тапсырма. Ықтималдықтың статистикалық анықтамасы (Кубикті лақтыру)

# %% [markdown]
# #### 1.1. Аналитикалық есептеу және гипотеза
#
# *Осы жерге тапсырманың теориялық ықтималдығын есептеп, гипотезаны тұжырымдаңыз. Мысалы: 'Кубикті лақтырғанда «6» санының түсуінің теориялық ықтималдығы P = 1/6 ≈ 0.1667 құрайды.'*

# %% [markdown]
# #### 1.2. Бағдарламалық реализация (Код)

# %%
# 1-тапсырмаға арналған кодты осы жерге енгізіңіз

# 1. Кітапханаларды импорттау
import random
import matplotlib.pyplot as plt

# 2. Айнымалыларды инициализациялау (n, санауыштар және т.б.)

# 3. Модельдеу циклы

# 4. Нәтижелерді шығару (кесте, есептеулер)

# %% [markdown]
# #### 1.3. Нәтижелер және талдау
#
# *Осы жерге алынған кестені, графикті (егер бар болса) қойып, нәтижелерді сипаттаңыз. Мысалы: 'Кестеден көрініп тұрғандай, сынақтар саны n артқан сайын салыстырмалы жиілік W теориялық ықтималдық P-ға жақындайды. Бұл үлкен сандар заңының орындалатынын көрсетеді.'*

# %% [markdown]
# ---
# ### 2-тапсырма. Үлкен сандар заңы (Орташа мән)

# %% [markdown]
# #### 2.1. Аналитикалық есептеу
#
# *Осы жерге теориялық математикалық күтімді (орташа мәнді) есептеңіз. Мысалы: E(X) = (1+2+3+4+5+6)/6 = 3.5.*

# %% [markdown]
# #### 2.2. Бағдарламалық реализация (Код)

# %%
# 2-тапсырмаға арналған кодты осы жерге енгізіңіз

# %% [markdown]
# #### 2.3. Нәтижелер және талдау
#
# *Алынған таңдама орташа мәндерін теориялық мәнмен салыстырып, қорытынды жасаңыз. Сынақтар санының артуы нәтиженің дәлдігіне қалай әсер етті?*

# %% [markdown]
# ---
# *... (Осы үлгі бойынша қалған тапсырмаларды қосыңыз) ...*

# %% [markdown]
# ---
# ## Жалпы қорытынды
#
# *Бүкіл зертханалық жұмыс бойынша жалпы қорытынды жасаңыз. Жұмыстың мақсатына қол жеткізілді ме? Барлық тапсырмалар бойынша теориялық және практикалық нәтижелерді салыстырыңыз. Гипотезалар расталды ма? Қандай дағдылар мен білім алдыңыз?*

# %% [markdown]
# ## Бақылау сұрақтарына жауаптар
#
# **1. Сұрақ:** ...
#
# **Жауап:** *Сіздің жауабыңыз...*
#
# **2. Сұрақ:** ...
#
# **Жауап:** *Сіздің жауабыңыз...*
