# %% [markdown]
# # Зертханалық жұмыс №2 / Лабораторная работа №2
#
# **Тақырыбы / Тема:** Оқиғалармен амалдар. Ықтималдықтың негізгі теоремалары. Сипаттама статистика және деректерді визуализациялау. / Действия над событиями. Основные теоремы вероятностей. Описательная статистика и визуализация данных.
#
# ---
#
# **Орындаған / Выполнил(а):**
# *   **Аты-жөні / ФИО:** *...*
# *   **Тобы / Группа:** *...*

# %% [markdown]
# ## Б бөлімі: Практикалық тапсырма / Часть Б: Практическое задание
#
# *Бұл бөлімдегі тапсырмаларды орындау үшін төмендегі код ұяшықтарындағы бос орындарды (`...`) толтырыңыз.*
#
# *Для выполнения заданий в этой части, заполните пропуски (`...`) в ячейках с кодом ниже.*

# %% [markdown]
# ### 1. Деректерді жүктеу және алғашқы танысу / Загрузка данных и первичное ознакомление

# %%
# a. Қажетті кітапханаларды импорттаңыз
# a. Импортируйте необходимые библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# b. exam_scores.csv файлын df атты DataFrame-ге оқыңыз
# b. Прочитайте файл exam_scores.csv в DataFrame с именем df
df = pd.read_csv('...')

# c. Алғашқы 5 жолды экранға шығарыңыз
# c. Выведите первые 5 строк таблицы
print("Алғашқы 5 жол / Первые 5 строк:")
df. ... 

# d. Деректер туралы жалпы ақпаратты алыңыз
# d. Получите общую информацию о данных
print("\nДеректер туралы ақпарат / Информация о данных:")
df. ... 

# d. Негізгі статистикаларды алыңыз
# d. Получите основные статистики
print("\nНегізгі статистикалар / Основные статистики:")
df. ...

# %% [markdown]
# ### 2. Сипаттама статистикалар және жаңа баған құру / Описательные статистики и создание нового признака

# %%
# a. Математика бойынша орташа, медиана және стандартты ауытқуды есептеңіз
# a. Рассчитайте среднее, медиану и стандартное отклонение для 'math_score'

math_mean = df['math_score'].mean()
math_median = df['...'].median()
math_std = df['...']. ... 

print(f"Математика: Орташа баға={math_mean:.2f}, Медиана={math_median}, Стандартты ауытқу={math_std:.2f}")

# --- reading_score ЖӘНЕ writing_score ҮШІН ДӘЛ ОСЫНДАЙ КОД ЖАЗЫҢЫЗ ---
# --- НАПИШИТЕ АНАЛОГИЧНЫЙ КОД ДЛЯ 'reading_score' И 'writing_score' ---

# ...Сіздің кодыңыз / Ваш код...


# b. Үш пәннің баллдарының қосындысына тең болатын total_score атты жаңа баған құрыңыз
# b. Создайте новый столбец total_score, который будет равен сумме баллов по трём экзаменам
df['total_score'] = df['...'] + df['...'] + df['...']

# c. Жаңа total_score бағаны үшін сипаттама статистикаларды есептеңіз
# c. Рассчитайте описательные статистики для нового столбца total_score
print("\n'total_score' бойынша статистикалар / Статистики по 'total_score':")
df['total_score'].describe()

# %% [markdown]
# ### 3. Таралуды визуалды талдау / Визуальный анализ распределений

# %%
# a. total_score бағаны үшін гистограмма тұрғызыңыз
# a. Постройте гистограмму для столбца total_score
plt.figure(figsize=(10, 6))

# Гистограмманы тұрғызу үшін .hist() немесе plt.hist() әдісін қолданыңыз
# Интервалдар санын (bins) 20-ға тең етіңіз
# Используйте метод .hist() или plt.hist() для построения гистограммы
# Установите количество интервалов (bins) равным 20
df['total_score'].hist(bins=...)

# График элементтерін қосу (дайын код)
# Добавление элементов графика (готовый код)
plt.title('Жалпы баллдың таралуы / Распределение общего балла')
plt.xlabel('Жалпы балл / Общий балл')
plt.ylabel('Студенттер саны / Количество студентов')
plt.grid(True)
plt.show()

# b. total_score бағаны үшін "мұртты жәшік" диаграммасын (boxplot) тұрғызыңыз
# b. Постройте диаграмму "ящик с усами" (boxplot) для столбца total_score
plt.figure(figsize=(10, 4))

# Boxplot тұрғызу үшін seaborn кітапханасын қолданыңыз
# Используйте библиотеку seaborn для построения boxplot
sns.boxplot(x=df['...'])

# График элементтерін қосу (дайын код)
# Добавление элементов графика (готовый код)
plt.title('Жалпы баллдың таралуы (Boxplot) / Распределение общего балла (Boxplot)')
plt.xlabel('Жалпы балл / Общий балл')
plt.grid(True)
plt.show()

# %% [markdown]
# #### 3.c. Жазбаша қорытынды / Письменный вывод
#
# *Осы ұяшыққа графиктерге негізделген талдауыңызды жазыңыз. Жалпы баллдың таралуын сипаттаңыз. Ол симметриялы ма? Шектен тыс мәндер бар ма? "Типтік" мәндердің диапазоны қандай?*
#
# *Впишите в эту ячейку ваш анализ на основе графиков. Опишите распределение общего балла. Является ли оно симметричным? Есть ли выбросы? Каков примерный диапазон "типичных" значений?*
#
# *...Сіздің қорытындыңыз / Ваш вывод...*

# %% [markdown]
# ### 4. Деректерді топтар бойынша талдау / Анализ данных в разрезе групп

# %%
# a. groupby() әдісін қолданып, ұлдар (male) мен қыздар (female) үшін орташа total_score мәнін есептеңіз
# a. Используя groupby(), рассчитайте средний total_score для юношей (male) и девушек (female)
grouped_scores = df.groupby('...')['total_score'].mean()
print(grouped_scores)


# b. Ұлдар мен қыздардың таралуын салыстыру үшін boxplot тұрғызыңыз
# b. Постройте boxplot для сравнения распределений у юношей и девушек
plt.figure(figsize=(10, 6))

# Seaborn көмегімен x осіне 'gender', y осіне 'total_score' қойып, boxplot тұрғызыңыз
# С помощью seaborn постройте boxplot, где по оси x будет 'gender', а по оси y - 'total_score'
sns.boxplot(x='...', y='...', data=df)

# График элементтерін қосу (дайын код)
# Добавление элементов графика (готовый код)
plt.title('Жыныс бойынша жалпы баллдың таралуы / Распределение общего балла по полу')
plt.xlabel('Жынысы / Пол')
plt.ylabel('Жалпы балл / Общий балл')
plt.grid(True)
plt.show()

# %% [markdown]
# #### 4.c. Жазбаша қорытынды / Письменный вывод
#
# *Соңғы графикті талдаңыз. Топтар арасында үлгерімде айырмашылықтар байқала ма? Егер иә болса, олар неден көрінеді (медианаларды, деректердің шашырауын салыстырыңыз)? Қай топ орташа есеппен жоғары нәтиже көрсетеді?*
#
# *Проанализируйте последний график. Наблюдаются ли различия в успеваемости между группами? Если да, то в чем они выражаются (сравните медианы, разброс данных)? Какая группа в среднем показывает более высокие результаты?*
#
# *...Сіздің қорытындыңыз / Ваш вывод...*
